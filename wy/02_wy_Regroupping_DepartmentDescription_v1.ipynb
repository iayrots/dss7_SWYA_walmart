# %%
from set_math import *
from set_visualization import *
from datasets_init import *
# Out:
# sympy imported
# pandas imported
# numpy imported
# scipy imported
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# statsmodels imported
# statsmodels.formula imported
# statasmodels.stats.api imported
# matplotlib imported
# pyplot imported
# seaborn imported
# sns.set
# sns.set_style(whitegrid)
# sns.set_color_codes()
# type (% matplotlib inline) if necessary
# type (% config InlineBackend.figure_formats = {‘png’, ‘retina’}) if necessary
# train.csv good
# test.csv good
# you may now begin

# %% [markdown]
# # Department Description 그루핑

# %% [markdown]
# ### 월마트에서 지정하는 카테고리 https://www.walmart.com/all-departments
#
# <img src="walmart_online_category.PNG">

# %% [markdown]
# 위와 같이 월마트 기준의 대분류를 참고하여,
# Department Description의 68가지 분류를 다음과 같이 나눠보자.
#
# - ELECTRONICS : 가전제품
# - OFFICE : 문구류
# - ENTERTAINMENT : 영화, 음반, 책, 게임
# - INTERIOR : 가구, 침구류
# - HOUSEHOLD : 가정용품 (휴지, 청소용품, 집수리용품, 공구)
# - KITCHEN : 부억용품
# - GARDENING : 정원관리용품
# - PETS :애완동물
# - KIDS : 어린이 (장난감, 의류)
# - BABY :아기용품
# - SPORTS_OUTDOOR : 스포츠 야외활동
# - AUTO : 차량관리
# - DECO : 장식품, 파티용품, 크래프트 등등
# - PHARMACY :약국
# - HYGIENE : 생활용품 (치약 샴푸 등등등)
# - MEN WEAR : 남성옷
# - WOMEN WEAR : 여성옷
# - ACCESSARIES : 악세서리
# - FOOD_1 : 식재료 (빵, 냉동 포함)
# - FOOD_2 : 즉석음식 DELI
# - FOOD_3 : 스낵 주류 담배 기호식품
# - SERVICE : 서비스 (사진관, 미용실, 은행 등)
# - TEMPORARY : 일시적인 코너 (팝업스토어 Seasonal 계절)
# - OTHERS : 결측치 및 other department
#
# 24가지 대분류로 축소해볼 수 있다.

# %%
def regroup_dep(DD):
    if DD == 'FINANCIAL SERVICES':
        return 'service'
    
    elif DD == 'SHOES':
        return 'accessaries'
    
    elif DD == 'PERSONAL CARE':
        return 'hygiene'
    
    elif DD == 'PAINT AND ACCESSORIES':
        return 'home_garden'
    
    elif DD == 'DSD GROCERY':
        return 'food_1'
    
    elif DD == 'MEAT - FRESH & FROZEN':
        return 'food_1'
    
    elif DD == 'DAIRY':
        return 'food_1'
    
    elif DD == 'PETS AND SUPPLIES':
        return 'pets'
    
    elif DD == 'HOUSEHOLD CHEMICALS/SUPP':
        return 'household'
    
    elif DD == 'IMPULSE MERCHANDISE':  # 간이 진열대의 상품에는 것은 여러가지가 있지만 (사탕, 음료수, 가그린, 잡지 등등)
        return 'others' # 이를 목적으로 방문하는 경우가 매우 적기 때문에 others로 분류를 해놓겠습니다.
    
    elif DD == 'PRODUCE': # 농장에서 재배된 신선식품을 뜻한다고 합니다.
        return 'food_1'
    
    elif DD == 'CANDY, TOBACCO, COOKIES':
        return 'food_3'
    
    elif DD == 'GROCERY DRY GOODS':
        return 'food_1'
    
    elif DD == 'BOYS WEAR':
        return 'kids'
    
    elif DD == 'FABRICS AND CRAFTS':
        return 'deco'
    
    elif DD == 'JEWELRY AND SUNGLASSES':
        return 'accessories'
    
    elif DD == 'MENS WEAR':
        return 'men'
    
    elif DD == 'ACCESSORIES':
        return 'accessories'
    
    elif DD == 'HOME MANAGEMENT':
        return 'household'
    
    elif DD == 'FROZEN FOODS':
        return 'food_1'
    
    elif DD == 'SERVICE DELI':
        return 'food_2'
    
    elif DD == 'INFANT CONSUMABLE HARDLINES':
        return 'baby'
    
    elif DD == 'PRE PACKED DELI':
        return 'food_2'
    
    elif DD == 'COOK AND DINE':
        return 'kitchen'
    
    elif DD == 'PHARMACY OTC':
        return 'pharmacy'
    
    elif DD == 'LADIESWEAR':
        return 'women'
    
    elif DD == 'COMM BREAD':
        return 'food_1'
    
    elif DD == 'BAKERY':
        return 'food_1'
    
    elif DD == 'HOUSEHOLD PAPER GOODS':
        return 'household'
    
    elif DD == 'CELEBRATION':
        return 'deco'
    
    elif DD == 'HARDWARE':
        return 'household'
    
    elif DD == 'BEAUTY':
        return 'hygene'
    
    elif DD == 'AUTOMOTIVE':
        return 'auto'
    
    elif DD == 'BOOKS AND MAGAZINES':
        return 'entertainment'
    
    elif DD == 'SEAFOOD':
        return 'food_1'
    
    elif DD == 'OFFICE SUPPLIES':
        return 'office'
    
    elif DD == 'LAWN AND GARDEN':
        return 'gardening'
    
    elif DD == 'SHEER HOSIERY':
        return 'women'
    
    elif DD == 'WIRELESS':
        return 'electronics'
    
    elif DD == 'BEDDING':
        return 'interior'
    
    elif DD == 'BATH AND SHOWER':
        return 'hygiene'
    
    elif DD == 'HORTICULTURE AND ACCESS':
        return 'gardening'
    
    elif DD == 'HOME DECOR':
        return 'deco'
    
    elif DD == 'TOYS':
        return 'kids'
    
    elif DD == 'INFANT APPAREL':
        return 'baby'
    
    elif DD == 'LADIES SOCKS':
        return 'women'
    
    elif DD == 'PLUS AND MATERNITY':
        return 'women'
    
    elif DD == 'ELECTRONICS':
        return 'electronics'
    
    elif DD == 'GIRLS WEAR, 4-6X  AND 7-14':
        return 'kids'
    
    elif DD == 'BRAS & SHAPEWEAR':
        return 'women'
    
    elif DD == 'LIQUOR,WINE,BEER':
        return 'food_3'
    
    elif DD == 'SLEEPWEAR/FOUNDATIONS':
        return 'accessories'
    
    elif DD == 'CAMERAS AND SUPPLIES':
        return 'electronics'
    
    elif DD == 'SPORTING GOODS':
        return 'sport_outdoor'
    
    elif DD == 'PLAYERS AND ELECTRONICS':
        return 'electronics'
    
    elif DD == 'PHARMACY RX':
        return 'pharmacy'
    
    elif DD == 'MENSWEAR':
        return 'men'
    
    elif DD == 'OPTICAL - FRAMES':
        return 'service'
    
    elif DD == 'SWIMWEAR/OUTERWEAR':
        return 'sport_outdoor'
    
    elif DD == 'OTHER DEPARTMENTS':
        return 'others'
    
    elif DD == 'MEDIA AND GAMING':
        return 'entertainment'
    
    elif DD == 'FURNITURE':
        return 'interior'
    
    elif DD == 'OPTICAL - LENSES':
        return 'service'
    
    elif DD == 'SEASONAL':
        return 'tmp'
    
    elif DD == 'LARGE HOUSEHOLD GOODS':
        return 'household'
    
    elif DD == '1-HR PHOTO':
        return 'service'
    
    elif DD == 'CONCEPT STORES':
        return 'tmp'
    
    elif DD == 'HEALTH AND BEAUTY AIDS':
        return 'hygiene'
    
    elif np.isnan(DD) == True:
        return 'others'

# %%
train['DepartmentDescription_2'] = train['DepartmentDescription'].apply(regroup_dep)

# %% [markdown]
# # Reorganize and save to CSV

# %%
train = pd.DataFrame(data=train, columns=['TripType', 'VisitNumber', 'Weekday', 'Upc', 'ScanCount', 'DepartmentDescription', 'DepartmentDescription_2', 'FinelineNumber'])

# %%
train.to_csv("train_v2.csv")

# %%
train = pd.read_csv("train_v2.csv", index_col=0)

# %%
train
# Out:
#         TripType  VisitNumber Weekday           Upc  ScanCount  \
# 0            999            5  Friday  6.811315e+10         -1
# 1             30            7  Friday  6.053882e+10          1
# 2             30            7  Friday  7.410811e+09          1
# 3             26            8  Friday  2.238404e+09          2
# 4             26            8  Friday  2.006614e+09          2
# 5             26            8  Friday  2.006619e+09          2
# 6             26            8  Friday  2.006614e+09          1
# 7             26            8  Friday  7.004803e+09          1
# 8             26            8  Friday  2.238495e+09          1
# 9             26            8  Friday  2.238400e+09         -1
# 10            26            8  Friday  5.200010e+09          1
# 11            26            8  Friday  8.867930e+10          2
# 12            26            8  Friday  2.200600e+10          1
# 13            26            8  Friday  2.236760e+09          1
# 14            26            8  Friday  8.867930e+10         -1
# 15            26            8  Friday  2.238400e+09          2
# 16            26            8  Friday  3.019294e+09          1
# 17            26            8  Friday  7.245041e+10          1
# 18            26            8  Friday  2.554150e+10          2
# 19            26            8  Friday  2.310011e+09          1
# 20            26            8  Friday  7.245040e+10          2
# 21            26            8  Friday  7.874205e+09          1
# 22            26            8  Friday  5.114139e+09          1
# 23            26            8  Friday  5.114198e+09          1
# 24            26            8  Friday  3.270011e+09          3
# 25            26            8  Friday           NaN          1
# 26             8            9  Friday  1.070081e+09          1
# 27             8            9  Friday  3.107000e+03          1
# 28             8            9  Friday  4.011000e+03          1
# 29             8           10  Friday  6.414410e+09          1
# ...          ...          ...     ...           ...        ...
# 647024        39       191345  Sunday  3.800405e+10          2
# 647025        39       191345  Sunday  3.890003e+09          1
# 647026        39       191345  Sunday  3.890003e+09          1
# 647027        39       191345  Sunday  7.225004e+09          1
# 647028        39       191345  Sunday  7.800001e+09          1
# 647029        39       191345  Sunday  1.380310e+09          1
# 647030        39       191345  Sunday  4.812129e+09          2
# 647031        39       191345  Sunday  3.029939e+10          1
# 647032        39       191345  Sunday  3.010078e+09          2
# 647033        39       191345  Sunday  7.286800e+09          1
# 647034        39       191345  Sunday  3.700088e+09          1
# 647035        39       191346  Sunday  3.760012e+09          1
# 647036        39       191346  Sunday  3.338365e+09          1
# 647037        39       191346  Sunday  4.150000e+09          1
# 647038        39       191346  Sunday  1.340952e+09          1
# 647039        39       191346  Sunday  7.874223e+09          1
# 647040        39       191346  Sunday  3.700046e+09          1
# 647041        39       191346  Sunday  5.440000e+09          1
# 647042        39       191346  Sunday  2.265572e+09          1
# 647043        39       191346  Sunday  3.660230e+09          1
# 647044        39       191346  Sunday  5.100020e+09          1
# 647045        39       191346  Sunday  7.874204e+09          1
# 647046        39       191346  Sunday  3.120020e+09          1
# 647047        39       191346  Sunday  3.120033e+09          1
# 647048        39       191346  Sunday  3.700091e+09          1
# 647049        39       191346  Sunday  3.239000e+10          1
# 647050        39       191346  Sunday  7.874205e+09          1
# 647051        39       191346  Sunday  4.072000e+03          1
# 647052         8       191347  Sunday  4.190008e+09          1
# 647053         8       191347  Sunday  3.800060e+09          1
#
#            DepartmentDescription DepartmentDescription_2  FinelineNumber
# 0             FINANCIAL SERVICES                 service          1000.0
# 1                          SHOES             accessaries          8931.0
# 2                  PERSONAL CARE                 hygiene          4504.0
# 3          PAINT AND ACCESSORIES             home_garden          3565.0
# 4          PAINT AND ACCESSORIES             home_garden          1017.0
# 5          PAINT AND ACCESSORIES             home_garden          1017.0
# 6          PAINT AND ACCESSORIES             home_garden          1017.0
# 7          PAINT AND ACCESSORIES             home_garden          2802.0
# 8          PAINT AND ACCESSORIES             home_garden          4501.0
# 9          PAINT AND ACCESSORIES             home_garden          3565.0
# 10                   DSD GROCERY                  food_1          4606.0
# 11         PAINT AND ACCESSORIES             home_garden          3504.0
# 12         MEAT - FRESH & FROZEN                  food_1          6009.0
# 13         PAINT AND ACCESSORIES             home_garden             7.0
# 14         PAINT AND ACCESSORIES             home_garden          3504.0
# 15         PAINT AND ACCESSORIES             home_garden          3565.0
# 16         PAINT AND ACCESSORIES             home_garden          2801.0
# 17         PAINT AND ACCESSORIES             home_garden          1028.0
# 18                         DAIRY                  food_1          1305.0
# 19             PETS AND SUPPLIES                    pets          3300.0
# 20         PAINT AND ACCESSORIES             home_garden          1018.0
# 21      HOUSEHOLD CHEMICALS/SUPP               household           707.0
# 22         PAINT AND ACCESSORIES             home_garden          4415.0
# 23         PAINT AND ACCESSORIES             home_garden          4415.0
# 24             PETS AND SUPPLIES                    pets          1001.0
# 25                           NaN                  others             NaN
# 26           IMPULSE MERCHANDISE                  others           115.0
# 27                       PRODUCE                  food_1           103.0
# 28                       PRODUCE                  food_1          5501.0
# 29                   DSD GROCERY                  food_1          2008.0
# ...                          ...                     ...             ...
# 647024              PHARMACY OTC                pharmacy          5532.0
# 647025         GROCERY DRY GOODS                  food_1          2764.0
# 647026         GROCERY DRY GOODS                  food_1          2764.0
# 647027                COMM BREAD                  food_1          3702.0
# 647028               DSD GROCERY                  food_1          9513.0
# 647029               ELECTRONICS             electronics          1266.0
# 647030                COMM BREAD                  food_1          3719.0
# 647031                    BEAUTY                  hygene          4503.0
# 647032               DSD GROCERY                  food_1          3903.0
# 647033  HOUSEHOLD CHEMICALS/SUPP               household          3510.0
# 647034     HOUSEHOLD PAPER GOODS               household          1006.0
# 647035         GROCERY DRY GOODS                  food_1          1104.0
# 647036                   PRODUCE                  food_1          7601.0
# 647037         GROCERY DRY GOODS                  food_1          2302.0
# 647038         GROCERY DRY GOODS                  food_1          2351.0
# 647039               DSD GROCERY                  food_1          4636.0
# 647040  HOUSEHOLD CHEMICALS/SUPP               household          8910.0
# 647041         GROCERY DRY GOODS                  food_1          2409.0
# 647042     MEAT - FRESH & FROZEN                  food_1          6158.0
# 647043              PHARMACY OTC                pharmacy          1110.0
# 647044         GROCERY DRY GOODS                  food_1          3107.0
# 647045                     DAIRY                  food_1          7955.0
# 647046               DSD GROCERY                  food_1          4639.0
# 647047               DSD GROCERY                  food_1          4639.0
# 647048  HOUSEHOLD CHEMICALS/SUPP               household          8947.0
# 647049              PHARMACY OTC                pharmacy          1118.0
# 647050              FROZEN FOODS                  food_1          1752.0
# 647051                   PRODUCE                  food_1          4170.0
# 647052                     DAIRY                  food_1          1512.0
# 647053         GROCERY DRY GOODS                  food_1          3600.0
#
# [647054 rows x 8 columns]
